# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(3*np.pi/2,60,100)
x = np.linspace(0.001,60,100)

# %%
plt.plot(x,np.sin(x) + 1)

# %%
plt.plot(x, -1/(x+np.pi+1)+1)

# %%
plt.plot(x, -np.sin(x)/(x*1.07**x) + 1)
